# %%
import pandas as pd

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Projects/Kaggle/CommonLit Readability/input/train.csv')
df_train.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
df_train.shape
# Out:
# (2834, 6)

# %%
df_test = pd.read_csv('/content/drive/MyDrive/Projects/Kaggle/CommonLit Readability/input/test.csv')
df_test.head()
# Out:
#           id  ...                                            excerpt
# 0  c0f722661  ...  My hope lay in Jack's promise that he would ke...
# 1  f0953f0a5  ...  Dotty continued to go to Mrs. Gray's every nig...
# 2  0df072751  ...  It was a bright and cheerful scene that greete...
# 3  04caf4e0c  ...  Cell division is the process by which a parent...
# 4  0e63f8bea  ...  Debugging is the process of finding and resolv...
#
# [5 rows x 4 columns]

# %%
df_test.shape
# Out:
# (7, 4)
